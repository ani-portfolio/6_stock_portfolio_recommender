# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pandas_gbq

from sklearn.preprocessing import StandardScaler

from google.cloud import bigquery
from google.cloud.exceptions import NotFound

from tqdm import tqdm
import yfinance as yf

# %% [markdown]
# # Query from CSV

# %%
df_enriched_stock_data = pd.read_csv('/Users/ani/Projects/6_stock_portfolio_recommendation/data//enriched_stock_data.csv')
df_enriched_stock_data
# Out:
#     Ticker  Closing_Price  All_Time_High  Percent_From_All_Time_High  \
# 0     MSFT         487.27         487.27                        0.00
# 1     NVDA         144.28         149.41                       -3.43
# 2     AAPL         201.95         258.40                      -21.85
# 3     AMZN         209.62         242.06                      -13.40
# 4    GOOGL         163.90         205.89                      -20.39
# ..     ...            ...            ...                         ...
# 496    ALB          56.83         313.32                      -81.86
# 497    IVZ          14.88          24.58                      -39.45
# 498    MHK         102.00         229.74                      -55.60
# 499    CZR          28.26         119.49                      -76.35
# 500   ENPH          34.88         336.00                      -89.62
#
#      Percent_Difference_200_Day_Moving_Average  24_Hour_Percent_Change  \
# 0                                        16.05                    2.07
# 1                                        12.52                    0.30
# 2                                        -9.56                    0.47
# 3                                         2.70                   -0.03
# 4                                        -4.40                   -1.64
# ..                                         ...                     ...
# 496                                     -29.27                    0.30
# 497                                      -7.66                    0.48
# 498                                     -18.31                    2.48
# 499                                     -16.54                    0.39
# 500                                     -49.00                   -2.71
#
#      7_Day_Percent_Change  30_Day_Percent_Change  Annualized_Return  \
# 0                    3.10                  11.41              16.65
# 1                    1.02                  22.94              57.59
# 2                    1.59                   2.39              14.62
# 3                   -1.68                   9.13               7.19
# 4                   -7.58                   6.37              14.49
# ..                    ...                    ...                ...
# 496                -12.11                  -0.42              -3.84
# 497                 -1.26                   2.26               8.32
# 498                 -2.59                  -2.96              -0.30
# 499                  1.29                   1.55              -7.11
# 500                -22.97                 -28.89              -4.33
#
#      YTD_Return  ...                  Sector  \
# 0         16.86  ...              Technology
# 1          4.33  ...              Technology
# 2        -16.98  ...              Technology
# 3         -4.81  ...       Consumer Cyclical
# 4        -13.27  ...  Communication Services
# ..          ...  ...                     ...
# 496      -32.51  ...         Basic Materials
# 497      -13.58  ...      Financial Services
# 498      -12.01  ...       Consumer Cyclical
# 499      -13.29  ...       Consumer Cyclical
# 500      -51.12  ...              Technology
#
#                                Industry        Country  \
# 0             Software - Infrastructure  United States
# 1                        Semiconductors  United States
# 2                  Consumer Electronics  United States
# 3                       Internet Retail  United States
# 4        Internet Content & Information  United States
# ..                                  ...            ...
# 496                 Specialty Chemicals  United States
# 497                    Asset Management  United States
# 498  Furnishings, Fixtures & Appliances  United States
# 499                   Resorts & Casinos  United States
# 500                               Solar  United States
#
#                                       Business_Summary  Dividend_Yield  \
# 0    Microsoft Corporation develops and supports so...            0.70
# 1    NVIDIA Corporation, a computing infrastructure...            0.03
# 2    Apple Inc. designs, manufactures, and markets ...            0.52
# 3    Amazon.com, Inc. engages in the retail sale of...            0.00
# 4    Alphabet Inc. offers various products and plat...            0.50
# ..                                                 ...             ...
# 496  Albemarle Corporation provides energy storage ...            2.86
# 497  Invesco Ltd. is a publicly owned investment ma...            5.67
# 498  Mohawk Industries, Inc. designs, manufactures,...            0.00
# 499  Caesars Entertainment, Inc. operates as a gami...            0.00
# 500  Enphase Energy, Inc., together with its subsid...            0.00
#
#      Trailing_PE  Forward_PE  Average_Volume Average_Volume_10days  \
# 0      37.656105   32.593310      22828664.0            18533110.0
# 1      46.392320   35.019444     251213522.0           173200140.0
# 2      31.495320   24.294222      61159585.0            55367100.0
# 3      34.122150   34.066666      48931716.0            39057090.0
# 4      18.278538   18.298939      40432375.0            36300310.0
# ..           ...         ...             ...                   ...
# 496     0.000000   30.885870       3520533.0             3122920.0
# 497    11.904560    7.873386       5743362.0             5694980.0
# 498    13.333333    9.147983        800620.0              908320.0
# 499     0.000000   21.089552       5669772.0             5448770.0
# 500    32.000000    9.530055       6951632.0            10263180.0
#
#      52_Week_Change
# 0          0.066411
# 1          0.217932
# 2         -0.034304
# 3          0.129978
# 4         -0.070193
# ..              ...
# 496       -0.412241
# 497       -0.032658
# 498       -0.117407
# 499       -0.278020
# 500       -0.668117
#
# [501 rows x 30 columns]

# %% [markdown]
# # Save to BigQuery

# %%
def create_schema(df):
    """Creates a BigQuery schema based on the DataFrame's columns and their data types.
    Args:
        df (pd.DataFrame): The DataFrame for which to create the schema.
    Returns:
        list: A list of bigquery.SchemaField objects representing the schema.
    """

    schema = []
    for col in df.columns:
        if df[col].dtype == 'float64':
            schema.append(bigquery.SchemaField(col, 'FLOAT'))
        elif df[col].dtype == 'int64':
            schema.append(bigquery.SchemaField(col, 'INTEGER'))
        else:
            schema.append(bigquery.SchemaField(col, 'STRING'))
    
    print(f"Created schema with {len(schema)} fields.")
    return schema
    
def save_table_to_bigquery(df, dataset_id, table_id):
    client = bigquery.Client()
    table_ref = client.dataset(dataset_id).table(table_id)
    
    # If the table does not exist, create it
    try:
        client.get_table(table_ref)
        print(f"Table {table_id} already exists in dataset {dataset_id}.")
        # delete the existing table
        client.delete_table(table_ref)
        print(f"Table {table_id} deleted from dataset {dataset_id}.")
    except NotFound:
        schema = create_schema(df)
        table = bigquery.Table(table_ref, schema=schema)
        table = client.create_table(table)
    print(f"Table {table_id} created in dataset {dataset_id}.")
    
    # Insert the DataFrame into the BigQuery table
    job = client.load_table_from_dataframe(df, table_ref)
    job.result()  # Wait for the job to complete

def load_table_from_bigquery(dataset_id, table_id, project_id):
    """Load a table from BigQuery."""

    query = f"SELECT * FROM `{dataset_id}.{table_id}`"
    df = pandas_gbq.read_gbq(query, project_id=project_id)
    return df

# %%
# Insert values in a table
save_table_to_bigquery(df=df_enriched_stock_data, dataset_id='stock_data', table_id='stock_data_test')
# Out:
# Table stock_data_test already exists in dataset stock_data.
# Table stock_data_test deleted from dataset stock_data.
# Table stock_data_test created in dataset stock_data.

# %% [markdown]
# # Load from BigQuery

# %%
df_enriched_stock_data = load_table_from_bigquery(dataset_id='stock_data', table_id='stock_data_test', project_id="capable-arbor-293714")
df_enriched_stock_data
# Out:
# Downloading: 100%|██████████|
#     Ticker  Closing_Price  All_Time_High  Percent_From_All_Time_High  \
# 0     CTVA          74.02          74.21                       -0.26
# 1       CF          96.82         111.25                      -12.97
# 2      MOS          35.92          72.25                      -50.28
# 3      VMC         259.05         291.14                      -11.02
# 4      MLM         547.22         617.09                      -11.32
# ..     ...            ...            ...                         ...
# 496    PNW          89.54          94.52                       -5.27
# 497    ATO         155.88         161.76                       -3.64
# 498     NI          40.31          40.94                       -1.54
# 499    AWK         143.31         175.80                      -18.48
# 500    CEG         314.99         346.32                       -9.05
#
#      Percent_Difference_200_Day_Moving_Average  24_Hour_Percent_Change  \
# 0                                        20.58                    0.41
# 1                                        15.50                   -3.52
# 2                                        30.95                   -1.16
# 3                                         0.56                    1.22
# 4                                         2.74                    1.67
# ..                                         ...                     ...
# 496                                       1.23                    1.10
# 497                                       7.47                    1.51
# 498                                       8.89                    2.00
# 499                                       5.20                    1.46
# 500                                      24.08                    3.30
#
#      7_Day_Percent_Change  30_Day_Percent_Change  Annualized_Return  \
# 0                    2.71                  10.98              19.16
# 1                    1.66                  19.76              24.07
# 2                    3.67                  12.05              20.45
# 3                   -0.79                  -3.31              14.54
# 4                    0.25                   1.19              17.78
# ..                    ...                    ...                ...
# 496                  0.37                  -2.68               7.53
# 497                  2.24                  -2.79              10.20
# 498                  2.15                   1.77              13.16
# 499                  1.92                  -0.85               3.87
# 500                  7.80                  16.57              66.79
#
#      YTD_Return  ...           Sector                        Industry  \
# 0         32.05  ...  Basic Materials             Agricultural Inputs
# 1         14.17  ...  Basic Materials             Agricultural Inputs
# 2         49.58  ...  Basic Materials             Agricultural Inputs
# 3          1.77  ...  Basic Materials              Building Materials
# 4          7.51  ...  Basic Materials              Building Materials
# ..          ...  ...              ...                             ...
# 496        8.34  ...        Utilities  Utilities - Regulated Electric
# 497       14.01  ...        Utilities       Utilities - Regulated Gas
# 498       12.50  ...        Utilities       Utilities - Regulated Gas
# 499       17.12  ...        Utilities     Utilities - Regulated Water
# 500       30.26  ...        Utilities           Utilities - Renewable
#
#            Country                                   Business_Summary  \
# 0    United States  Corteva, Inc. operates in the agriculture busi...
# 1    United States  CF Industries Holdings, Inc., together with it...
# 2    United States  The Mosaic Company, through its subsidiaries, ...
# 3    United States  Vulcan Materials Company produces and supplies...
# 4    United States  Martin Marietta Materials, Inc., a natural res...
# ..             ...                                                ...
# 496  United States  Pinnacle West Capital Corporation, through its...
# 497  United States  Atmos Energy Corporation, together with its su...
# 498  United States  NiSource Inc., an energy holding company, oper...
# 499  United States  American Water Works Company, Inc., through it...
# 500  United States  Constellation Energy Corporation produces and ...
#
#      Dividend_Yield  Trailing_PE  Forward_PE  Average_Volume  \
# 0              0.92    44.590360   23.059189       3815208.0
# 1              1.99    12.807539   15.667476       2789909.0
# 2              2.42    30.965517   14.601625       5762537.0
# 3              0.77    36.384130   28.530285       1124596.0
# 4              0.59    31.377007   26.257920        453570.0
# ..              ...          ...         ...             ...
# 496            4.04    17.730692   19.132479       1258969.0
# 497            2.27    21.766762   21.827732       1132853.0
# 498            2.83    21.789190   21.672043       4622620.0
# 499            2.34    26.074680   25.114035       1440667.0
# 500            0.51    33.226437   35.194035       3625591.0
#
#     Average_Volume_10days  52_Week_Change
# 0               5275200.0        0.393309
# 1               4192810.0        0.327513
# 2               7347690.0        0.248368
# 3                849750.0        0.033767
# 4                377270.0       -0.005451
# ..                    ...             ...
# 496             1416440.0        0.169550
# 497              794570.0        0.301135
# 498             4381450.0        0.368421
# 499             1053040.0        0.068619
# 500             2686490.0        0.411013
#
# [501 rows x 30 columns]
